# %% [markdown]
# # Detecting Payment Card Fraud
#
# In this section, we'll look at a credit card fraud detection dataset, and build a binary classification model that can identify transactions as either fraudulent or valid, based on provided, *historical* data. In a [2016 study](https://nilsonreport.com/upload/content_promo/The_Nilson_Report_10-17-2016.pdf), it was estimated that credit card fraud was responsible for over 20 billion dollars in loss, worldwide. Accurately detecting cases of fraud is an ongoing area of research.
#
# <img src=notebook_ims/fraud_detection.png width=50% />
#
# ### Labeled Data
#
# The payment fraud data set (Dal Pozzolo et al. 2015) was downloaded from [Kaggle](https://www.kaggle.com/mlg-ulb/creditcardfraud/data). This has features and labels for thousands of credit card transactions, each of which is labeled as fraudulent or valid. In this notebook, we'd like to train a model based on the features of these transactions so that we can predict risky or fraudulent transactions in the future.
#
# ### Binary Classification
#
# Since we have true labels to aim for, we'll take a **supervised learning** approach and train a binary classifier to sort data into one of our two transaction classes: fraudulent or valid.  We'll train a model on training data and see how well it generalizes on some test data.
#
# The notebook will be broken down into a few steps:
# * Loading and exploring the data
# * Splitting the data into train/test sets
# * Defining and training a LinearLearner, binary classifier
# * Making improvements on the model
# * Evaluating and comparing model test performance
#
# ### Making Improvements
#
# A lot of this notebook will focus on making improvements, as discussed in [this SageMaker blog post](https://aws.amazon.com/blogs/machine-learning/train-faster-more-flexible-models-with-amazon-sagemaker-linear-learner/). Specifically, we'll address techniques for:
#
# 1. **Tuning a model's hyperparameters** and aiming for a specific metric, such as high recall or precision.
# 2. **Managing class imbalance**, which is when we have many more training examples in one class than another (in this case, many more valid transactions than fraudulent).
#
# ---

# %% [markdown]
# First, import the usual resources.

# %%
import io
import os
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd 

import boto3
import sagemaker
from sagemaker import get_execution_role

# %matplotlib inline

# %% [markdown]
# I'm storing my **SageMaker variables** in the next cell:
# * sagemaker_session: The SageMaker session we'll use for training models.
# * bucket: The name of the default S3 bucket that we'll use for data storage.
# * role: The IAM role that defines our data and model permissions.

# %%
# sagemaker session, role
sagemaker_session = sagemaker.Session()
role = sagemaker.get_execution_role()

# S3 bucket name
bucket = sagemaker_session.default_bucket()

# %% [markdown]
# ## Loading and Exploring the Data
#
# Next, I am loading the data and unzipping the data in the file `creditcardfraud.zip`. This directory will hold one csv file of all the transaction data, `creditcard.csv`.
#
# As in previous notebooks, it's important to look at the distribution of data since this will inform how we develop a fraud detection model. We'll want to know: How many data points we have to work with, the number and type of features, and finally, the distribution of data over the classes (valid or fraudulent).

# %%
# only have to run once
# !wget https://s3.amazonaws.com/video.udacity-data.com/topher/2019/January/5c534768_creditcardfraud/creditcardfraud.zip
# !unzip creditcardfraud
# Out:
# --2020-12-28 19:15:36--  https://s3.amazonaws.com/video.udacity-data.com/topher/2019/January/5c534768_creditcardfraud/creditcardfraud.zip
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.216.106.61
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.216.106.61|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 69155632 (66M) [application/zip]
# Saving to: ‘creditcardfraud.zip’
#
# creditcardfraud.zip 100%[===================>]  65.95M  5.47MB/s    in 14s
#
# 2020-12-28 19:15:51 (4.88 MB/s) - ‘creditcardfraud.zip’ saved [69155632/69155632]
#
# Archive:  creditcardfraud.zip
#   inflating: creditcard.csv

# %%
# read in the csv file
local_data = 'creditcard.csv'

# print out some data
transaction_df = pd.read_csv(local_data)
print('Data shape (rows, cols): ', transaction_df.shape)
print()
transaction_df.head()
# Out:
# Data shape (rows, cols):  (284807, 31)
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %% [markdown]
# ### EXERCISE: Calculate the percentage of fraudulent data
#
# Take a look at the distribution of this transaction data over the classes, valid and fraudulent.
#
# Complete the function `fraudulent_percentage`, below. Count up the number of data points in each class and calculate the *percentage* of the data points that are fraudulent.

# %%
# Calculate the fraction of data points that are fraudulent
def fraudulent_percentage(transaction_df):
    '''Calculate the fraction of all data points that have a 'Class' label of 1; fraudulent.
       :param transaction_df: Dataframe of all transaction data points; has a column 'Class'
       :return: A fractional percentage of fraudulent data points/all points
    '''
    pos = transaction_df.Class.sum()/transaction_df.shape[0]
    # your code here
    return pos

# %% [markdown]
# Test out your code by calling your function and printing the result.

# %%
# call the function to calculate the fraud percentage
fraud_percentage = fraudulent_percentage(transaction_df)

print('Fraudulent percentage = ', str(fraud_percentage*100))
print('Total # of fraudulent pts: ', fraud_percentage*transaction_df.shape[0])
print('Out of (total) pts: ', transaction_df.shape[0])
# Out:
# Fraudulent percentage =  0.1727485630620034
# Total # of fraudulent pts:  492.0
# Out of (total) pts:  284807

# %% [markdown]
# ### EXERCISE: Split into train/test datasets
#
# In this example, we'll want to evaluate the performance of a fraud classifier; training it on some training data and testing it on *test data* that it did not see during the training process. So, we'll need to split the data into separate training and test sets.
#
# Complete the `train_test_split` function, below. This function should:
# * Shuffle the transaction data, randomly
# * Split it into two sets according to the parameter `train_frac`
# * Get train/test features and labels
# * Return the tuples: (train_features, train_labels), (test_features, test_labels)

# %%
# split into train/test
from sklearn.utils import shuffle
def train_test_split(transaction_df, train_frac= 0.7, seed=1):
    '''Shuffle the data and randomly split into train and test sets;
       separate the class labels (the column in transaction_df) from the features.
       :param df: Dataframe of all credit card transaction data
       :param train_frac: The decimal fraction of data that should be training data
       :param seed: Random seed for shuffling and reproducibility, default = 1
       :return: Two tuples (in order): (train_features, train_labels), (test_features, test_labels)
       '''
    df = transaction_df.values
    df = shuffle(df,random_state=seed)
    # shuffle and split the data
    idx = round(train_frac * transaction_df.shape[0])
    train_features = df[:idx,:-1]
    train_labels = df[:idx,-1]
    test_features = df[idx:,:-1]
    test_labels = df[idx:,-1]
    
    return (train_features, train_labels), (test_features, test_labels)

# %% [markdown]
# ### Test Cell
#
# In the cells below, I'm creating the train/test data and checking to see that result makes sense. The tests below test that the above function splits the data into the expected number of points and that the labels are indeed, class labels (0, 1).

# %%
# get train/test data
(train_features, train_labels), (test_features, test_labels) = train_test_split(transaction_df, train_frac=0.7)

# %%
# manual test

# for a split of 0.7:0.3 there should be ~2.33x as many training as test pts
print('Training data pts: ', len(train_features))
print('Test data pts: ', len(test_features))
print()

# take a look at first item and see that it aligns with first row of data
print('First item: \n', train_features[0])
print('Label: ', train_labels[0])
print()

# test split
assert len(train_features) > 2.333*len(test_features), \
        'Unexpected number of train/test points for a train_frac=0.7'
# test labels
assert np.all(train_labels)== 0 or np.all(train_labels)== 1, \
        'Train labels should be 0s or 1s.'
assert np.all(test_labels)== 0 or np.all(test_labels)== 1, \
        'Test labels should be 0s or 1s.'
print('Tests passed!')
# Out:
# Training data pts:  199365
# Test data pts:  85442
#
# First item:
#  [ 1.19907000e+05 -6.11711999e-01 -7.69705324e-01 -1.49759145e-01
#  -2.24876503e-01  2.02857736e+00 -2.01988711e+00  2.92491387e-01
#  -5.23020325e-01  3.58468461e-01  7.00499612e-02 -8.54022784e-01
#   5.47347360e-01  6.16448382e-01 -1.01785018e-01 -6.08491804e-01
#  -2.88559430e-01 -6.06199260e-01 -9.00745518e-01 -2.01311157e-01
#  -1.96039343e-01 -7.52077614e-02  4.55360454e-02  3.80739375e-01
#   2.34403159e-02 -2.22068576e+00 -2.01145578e-01  6.65013699e-02
#   2.21179560e-01  1.79000000e+00]
# Label:  0.0
#
# Tests passed!

# %% [markdown]
# ---
# # Modeling
#
# Now that you've uploaded your training data, it's time to define and train a model!
#
# In this notebook, you'll define and train the SageMaker, built-in algorithm, [LinearLearner](https://sagemaker.readthedocs.io/en/stable/linear_learner.html).
#
# A LinearLearner has two main applications:
# 1. For regression tasks in which a linear line is fit to some data points, and you want to produce a predicted output value given some data point (example: predicting house prices given square area).
# 2. For binary classification, in which a line is separating two classes of data and effectively outputs labels; either 1 for data that falls above the line or 0 for points that fall on or below the line.
#
# <img src='notebook_ims/linear_separator.png' width=50% />
#
# In this case, we'll be using it for case 2, and we'll train it to separate data into our two classes: valid or fraudulent.

# %% [markdown]
# ### EXERCISE: Create a LinearLearner Estimator
#
# You've had some practice instantiating built-in models in SageMaker. All estimators require some constructor arguments to be passed in. See if you can complete this task, instantiating a LinearLearner estimator, using only the [LinearLearner documentation](https://sagemaker.readthedocs.io/en/stable/linear_learner.html) as a resource. This takes in a lot of arguments, but not all are required. My suggestion is to start with a simple model, utilizing default values where applicable. Later, we will discuss some specific hyperparameters and their use cases.
#
# #### Instance Types
#
# It is suggested that you use instances that are available in the free tier of usage: `'ml.c4.xlarge'` for training and `'ml.t2.medium'` for deployment.

# %%
# import LinearLearner
from sagemaker import LinearLearner

# instantiate LinearLearner
linearmodel = LinearLearner(role = role,
                           instance_count=1,
                           instance_type='ml.c4.xlarge',
                           predictor_type ='binary_classifier')

# %% [markdown]
# ### EXERCISE: Convert data into a RecordSet format
#
# Next, prepare the data for a built-in model by converting the train features and labels into numpy array's of float values. Then you can use the [record_set function](https://sagemaker.readthedocs.io/en/stable/linear_learner.html#sagemaker.LinearLearner.record_set) to format the data as a RecordSet and prepare it for training!

# %%
# create RecordSet of training data
train_x = train_features.astype('float32')
train_y = train_labels.astype('float32')

formatted_train_data = linearmodel.record_set(train_x,labels = train_y)

# %% [markdown]
# ### EXERCISE: Train the Estimator
#
# After instantiating your estimator, train it with a call to `.fit()`, passing in the formatted training data.

# %%
# %%time 
# train the estimator on formatted training data
linearmodel.fit(formatted_train_data)
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# 2020-12-29 08:21:02 Starting - Starting the training job...
# 2020-12-29 08:21:27 Starting - Launching requested ML instancesProfilerReport-1609230062: InProgress
# ......
# 2020-12-29 08:22:28 Starting - Preparing the instances for training.........
# 2020-12-29 08:23:53 Downloading - Downloading input data
# 2020-12-29 08:23:53 Training - Downloading the training image..Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [12/29/2020 08:24:12 INFO 140145823393600] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'auto', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [12/29/2020 08:24:12 INFO 140145823393600] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {u'feature_dim': u'30', u'mini_batch_size': u'1000', u'predictor_type': u'binary_classifier'}
# [12/29/2020 08:24:12 INFO 140145823393600] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'30', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'binary_classifier', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [12/29/2020 08:24:12 WARNING 140145823393600] Loggers have already been setup.
# Process 1 is a worker.
# [12/29/2020 08:24:12 INFO 140145823393600] Using default worker.
# [12/29/2020 08:24:12 INFO 140145823393600] Checkpoint loading and saving are disabled.
# [2020-12-29 08:24:12.525] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration":
"Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609230347.295554}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012914280618255463, "sum": 0.012914280618255463, "min": 0.012914280618255463}}, "EndTime": 1609230347.295622, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609230347.295607}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012842341140886048, "sum": 0.012842341140886048, "min": 0.012842341140886048}}, "EndTime": 1609230347.29568, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609230347.295664}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01284956756249145, "sum": 0.01284956756249145, "min": 0.01284956756249145}}, "EndTime": 1609230347.295743, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609230347.295727}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012990586397036836, "sum": 0.012990586397036836, "min": 0.012990586397036836}}, "EndTime": 1609230347.295795, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609230347.295782}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012850412979796904, "sum": 0.012850412979796904, "min": 0.012850412979796904}}, "EndTime": 1609230347.295841, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609230347.295829}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012989185218235956, "sum": 0.012989185218235956, "min": 0.012989185218235956}}, "EndTime": 1609230347.295894, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609230347.295878}
#
# [12/29/2020 08:25:47 INFO 140145823393600] #quality_metric: host=algo-1, epoch=14, train binary_classification_cross_entropy_objective <loss>=0.0048651197969
# [12/29/2020 08:25:47 INFO 140145823393600] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=binary_classification_cross_entropy_objective, value=0.00418339715277
# [12/29/2020 08:25:47 INFO 140145823393600] Epoch 14: Loss improved. Updating best model
# [12/29/2020 08:25:47 INFO 140145823393600] Saving model for epoch: 14
# [12/29/2020 08:25:47 INFO 140145823393600] Saved checkpoint to "/tmp/tmptS8z5v/mx-mod-0000.params"
# [12/29/2020 08:25:47 INFO 140145823393600] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199365, "sum": 199365.0, "min": 199365}, "Total Batches Seen": {"count": 1, "max": 3012, "sum": 3012.0, "min": 3012}, "Total Records Seen": {"count": 1, "max": 3002475, "sum": 3002475.0, "min": 3002475}, "Max Records Seen Between Resets": {"count": 1, "max": 199365, "sum": 199365.0, "min": 199365}, "Reset Count": {"count": 1, "max": 17, "sum": 17.0, "min": 17}}, "EndTime": 1609230347.302495, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609230341.670761}
#
# [12/29/2020 08:25:47 INFO 140145823393600] #throughput_metric: host=algo-1, train throughput=35399.6642466 records/second
# [12/29/2020 08:25:47 WARNING 140145823393600] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [12/29/2020 08:25:47 WARNING 140145823393600] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2020-12-29 08:25:47.309] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 33, "duration": 5, "num_examples": 1, "num_bytes": 168000}
# [2020-12-29 08:25:47.942] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 36, "duration": 631, "num_examples": 200, "num_bytes": 33493320}
# [2020-12-29 08:25:48.707] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 38, "duration": 697, "num_examples": 200, "num_bytes": 33493320}
# [12/29/2020 08:25:48 INFO 140145823393600] #train_score (algo-1) : ('binary_classification_cross_entropy_objective', 0.004137363901699895)
# [12/29/2020 08:25:48 INFO 140145823393600] #train_score (algo-1) : ('binary_classification_accuracy', 0.9993027863466506)
# [12/29/2020 08:25:48 INFO 140145823393600] #train_score (algo-1) : ('binary_f_1.000', 0.8005738880918221)
# [12/29/2020 08:25:48 INFO 140145823393600] #train_score (algo-1) : ('precision', 0.8063583815028902)
# [12/29/2020 08:25:48 INFO 140145823393600] #train_score (algo-1) : ('recall', 0.7948717948717948)
# [12/29/2020 08:25:48 INFO 140145823393600] #train_score (algo-1) : ('roc_auc_score', 0.9774616494646241)
# [12/29/2020 08:25:48 INFO 140145823393600] #quality_metric: host=algo-1, train binary_classification_cross_entropy_objective <loss>=0.0041373639017
# [12/29/2020 08:25:48 INFO 140145823393600] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.999302786347
# [12/29/2020 08:25:48 INFO 140145823393600] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.800573888092
# [12/29/2020 08:25:48 INFO 140145823393600] #quality_metric: host=algo-1, train precision <score>=0.806358381503
# [12/29/2020 08:25:48 INFO 140145823393600] #quality_metric: host=algo-1, train recall <score>=0.794871794872
# [12/29/2020 08:25:48 INFO 140145823393600] #quality_metric: host=algo-1, train roc_auc_score <score>=0.977461649465
# [12/29/2020 08:25:48 INFO 140145823393600] Best model found for hyperparameters: {"lr_scheduler_step": 10, "wd": 0.0001, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.1, "lr_scheduler_minimum_lr": 0.0001}
# [12/29/2020 08:25:48 INFO 140145823393600] Saved checkpoint to "/tmp/tmppLAhcn/mx-mod-0000.params"
# [12/29/2020 08:25:48 INFO 140145823393600] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 96592.38505363464, "sum": 96592.38505363464, "min": 96592.38505363464}, "finalize.time": {"count": 1, "max": 1463.3510112762451, "sum": 1463.3510112762451, "min": 1463.3510112762451}, "initialize.time": {"count": 1, "max": 214.28704261779785, "sum": 214.28704261779785, "min": 214.28704261779785}, "check_early_stopping.time": {"count": 15, "max": 0.9410381317138672, "sum": 13.149023056030273, "min": 0.8130073547363281}, "setuptime": {"count": 1, "max": 39.3218994140625, "sum": 39.3218994140625, "min": 39.3218994140625}, "update.time": {"count": 15, "max": 7082.3869705200195, "sum": 94525.69794654846, "min": 5513.696193695068}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1609230348.771108, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1609230252.496816}
# 2020-12-29 08:25:57 Uploading - Uploading generated training model
# 2020-12-29 08:25:57 Completed - Training job completed
# Training seconds: 135
# Billable seconds: 135
# CPU times: user 794 ms, sys: 44.7 ms, total: 839 ms
# Wall time: 5min 12s

# %% [markdown]
# ### EXERCISE: Deploy the trained model
#
# Deploy your model to create a predictor. We'll use this to make predictions on our test data and evaluate the model.

# %%
# %%time 
# deploy and create a predictor
linear_predictor = linearmodel.deploy(initial_instance_count=1,instance_type='ml.t2.medium')
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# -----------------!CPU times: user 349 ms, sys: 9.37 ms, total: 358 ms
# Wall time: 8min 32s

# %% [markdown]
# ---
# # Evaluating Your Model
#
# Once your model is deployed, you can see how it performs when applied to the test data.
#
# According to the deployed [predictor documentation](https://sagemaker.readthedocs.io/en/stable/linear_learner.html#sagemaker.LinearLearnerPredictor), this predictor expects an `ndarray` of input features and returns a list of Records.
# > "The prediction is stored in the "predicted_label" key of the `Record.label` field."
#
# Let's first test our model on just one test point, to see the resulting list.

# %%
# test one prediction
test_x_np = test_features.astype('float32')
result = linear_predictor.predict(test_x_np[0])

print(result)
# Out:
# [label {
#   key: "predicted_label"
#   value {
#     float32_tensor {
#       values: 0.0
#     }
#   }
# }
# label {
#   key: "score"
#   value {
#     float32_tensor {
#       values: 0.0004113880277145654
#     }
#   }
# }
# ]

# %% [markdown]
# ### Helper function for evaluation
#
#
# The provided function below, takes in a deployed predictor, some test features and labels, and returns a dictionary of metrics; calculating false negatives and positives as well as recall, precision, and accuracy.

# %%
# code to evaluate the endpoint on test data
# returns a variety of model metrics
def evaluate(predictor, test_features, test_labels, verbose=True):
    """
    Evaluate a model on a test set given the prediction endpoint.  
    Return binary classification metrics.
    :param predictor: A prediction endpoint
    :param test_features: Test features
    :param test_labels: Class labels for test data
    :param verbose: If True, prints a table of all performance metrics
    :return: A dictionary of performance metrics.
    """
    
    # We have a lot of test data, so we'll split it into batches of 100
    # split the test data set into batches and evaluate using prediction endpoint    
    prediction_batches = [predictor.predict(batch) for batch in np.array_split(test_features, 100)]
    
    # LinearLearner produces a `predicted_label` for each data point in a batch
    # get the 'predicted_label' for every point in a batch
    test_preds = np.concatenate([np.array([x.label['predicted_label'].float32_tensor.values[0] for x in batch]) 
                                 for batch in prediction_batches])
    
    # calculate true positives, false positives, true negatives, false negatives
    tp = np.logical_and(test_labels, test_preds).sum()
    fp = np.logical_and(1-test_labels, test_preds).sum()
    tn = np.logical_and(1-test_labels, 1-test_preds).sum()
    fn = np.logical_and(test_labels, 1-test_preds).sum()
    
    # calculate binary classification metrics
    recall = tp / (tp + fn)
    precision = tp / (tp + fp)
    accuracy = (tp + tn) / (tp + fp + tn + fn)
    
    # printing a table of metrics
    if verbose:
        print(pd.crosstab(test_labels, test_preds, rownames=['actual (row)'], colnames=['prediction (col)']))
        print("\n{:<11} {:.3f}".format('Recall:', recall))
        print("{:<11} {:.3f}".format('Precision:', precision))
        print("{:<11} {:.3f}".format('Accuracy:', accuracy))
        print()
        
    return {'TP': tp, 'FP': fp, 'FN': fn, 'TN': tn, 
            'Precision': precision, 'Recall': recall, 'Accuracy': accuracy}

# %% [markdown]
# ### Test Results
#
# The cell below runs the `evaluate` function.
#
# The code assumes that you have a defined `predictor` and `test_features` and `test_labels` from previously-run cells.

# %%
print('Metrics for simple, LinearLearner.\n')

# get metrics for linear predictor
metrics = evaluate(linear_predictor, 
                   test_features.astype('float32'), 
                   test_labels, 
                   verbose=True) # verbose means we'll print out the metrics
# Out:
# Metrics for simple, LinearLearner.
#
# prediction (col)    0.0  1.0
# actual (row)
# 0.0               85268   33
# 1.0                  32  109
#
# Recall:     0.773
# Precision:  0.768
# Accuracy:   0.999

# %% [markdown]
# ## Delete the Endpoint
#
# I've added a convenience function to delete prediction endpoints after we're done with them. And if you're done evaluating the model, you should delete your model endpoint!

# %%
# Deletes a precictor.endpoint
def delete_endpoint(predictor):
        try:
            boto3.client('sagemaker').delete_endpoint(EndpointName=predictor.endpoint)
            print('Deleted {}'.format(predictor.endpoint))
        except:
            print('Already deleted: {}'.format(predictor.endpoint))

# %%
# delete the predictor endpoint 
delete_endpoint(linear_predictor)
# Out:
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Deleted linear-learner-2020-12-29-08-32-08-753

# %% [markdown]
# ---
#
# # Model Improvements
#
# The default LinearLearner got a high accuracy, but still classified fraudulent and valid data points incorrectly. Specifically classifying more than 30 points as false negatives (incorrectly labeled, fraudulent transactions), and a little over 30 points as false positives (incorrectly labeled, valid transactions). Let's think about what, during training, could cause this behavior and what we could improve.
#
# **1. Model optimization**
# * If we imagine that we are designing this model for use in a bank application, we know that users do *not* want any valid transactions to be categorized as fraudulent. That is, we want to have as few **false positives** (0s classified as 1s) as possible.
# * On the other hand, if our bank manager asks for an application that will catch almost *all* cases of fraud, even if it means a higher number of false positives, then we'd want as few **false negatives** as possible.
# * To train according to specific product demands and goals, we do not want to optimize for accuracy only. Instead, we want to optimize for a metric that can help us decrease the number of false positives or negatives.
#
# <img src='notebook_ims/precision_recall.png' width=40% />
#
# In this notebook, we'll look at different cases for tuning a model and make an optimization decision, accordingly.
#
# **2. Imbalanced training data**
# * At the start of this notebook, we saw that only about 0.17% of the training data was labeled as fraudulent. So, even if a model labels **all** of our data as valid, it will still have a high accuracy.
# * This may result in some overfitting towards valid data, which accounts for some **false negatives**; cases in which fraudulent data (1) is incorrectly characterized as valid (0).
#
# So, let's address these issues in order; first, tuning our model and optimizing for a specific metric during training, and second, accounting for class imbalance in the training set.

# %% [markdown]
# # Improvement: Model Tuning
#
# Optimizing according to a specific metric is called **model tuning**, and SageMaker provides a number of ways to automatically tune a model.
#
#
# ### Create a LinearLearner and tune for higher precision
#
# **Scenario:**
# * A bank has asked you to build a model that detects cases of fraud with an accuracy of about 85%.
#
# In this case, we want to build a model that has as many true positives and as few false negatives, as possible. This corresponds to a model with a high **recall**: true positives / (true positives + false negatives).
#
# To aim for a specific metric, LinearLearner offers the hyperparameter `binary_classifier_model_selection_criteria`, which is the model evaluation criteria for the training dataset. A reference to this parameter is in [LinearLearner's documentation](https://sagemaker.readthedocs.io/en/stable/linear_learner.html#sagemaker.LinearLearner). We'll also have to further specify the exact value we want to aim for; read more about the details of the parameters, [here](https://docs.aws.amazon.com/sagemaker/latest/dg/ll_hyperparameters.html).
#
# I will assume that performance on a training set will be within about 5% of the performance on a test set. So, for a recall of about 85%, I'll aim for a bit higher, 90%.

# %%
# instantiate a LinearLearner
# tune the model for a higher recall
prefix = 'creditcard'
output_path = 's3://{}/{}'.format(bucket, prefix)
linear_recall = LinearLearner(role=role,
                              train_instance_count=1, 
                              train_instance_type='ml.c4.xlarge',
                              predictor_type='binary_classifier',
                              output_path=output_path,
                              sagemaker_session=sagemaker_session,
                              epochs=15,
                              binary_classifier_model_selection_criteria='precision_at_target_recall', # target recall
                              target_recall=0.9) # 90% recall
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %% [markdown]
# ### Train the tuned estimator
#
# Fit the new, tuned estimator on the formatted training data.

# %%
# %%time 
# train the estimator on formatted training data
linear_recall.fit(formatted_train_data)
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# 2020-12-29 08:53:18 Starting - Starting the training job...
# 2020-12-29 08:53:42 Starting - Launching requested ML instancesProfilerReport-1609231998: InProgress
# ......
# 2020-12-29 08:54:43 Starting - Preparing the instances for training......
# 2020-12-29 08:55:44 Downloading - Downloading input data...
# 2020-12-29 08:56:19 Training - Training image download completed. Training in progress..Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [12/29/2020 08:56:23 INFO 139939743401792] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'auto', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [12
"Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609232276.549725}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012012594958046572, "sum": 0.012012594958046572, "min": 0.012012594958046572}}, "EndTime": 1609232276.549798, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609232276.549786}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011879369413433363, "sum": 0.011879369413433363, "min": 0.011879369413433363}}, "EndTime": 1609232276.549851, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609232276.549837}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012012267706382215, "sum": 0.012012267706382215, "min": 0.012012267706382215}}, "EndTime": 1609232276.549896, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609232276.549886}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012914269195729165, "sum": 0.012914269195729165, "min": 0.012914269195729165}}, "EndTime": 1609232276.549929, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609232276.549921}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012842971408187444, "sum": 0.012842971408187444, "min": 0.012842971408187444}}, "EndTime": 1609232276.549985, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609232276.549968}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012914280618255463, "sum": 0.012914280618255463, "min": 0.012914280618255463}}, "EndTime": 1609232276.550047, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609232276.550029}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012842341140886048, "sum": 0.012842341140886048, "min": 0.012842341140886048}}, "EndTime": 1609232276.550103, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609232276.550089}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01284956756249145, "sum": 0.01284956756249145, "min": 0.01284956756249145}}, "EndTime": 1609232276.550155, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609232276.550139}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012990586397036836, "sum": 0.012990586397036836, "min": 0.012990586397036836}}, "EndTime": 1609232276.550213, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609232276.550197}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012850412979796904, "sum": 0.012850412979796904, "min": 0.012850412979796904}}, "EndTime": 1609232276.55028, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609232276.550262}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012989185218235956, "sum": 0.012989185218235956, "min": 0.012989185218235956}}, "EndTime": 1609232276.550335, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609232276.550319}
#
# [12/29/2020 08:57:56 INFO 139939743401792] #quality_metric: host=algo-1, epoch=14, train binary_classification_cross_entropy_objective <loss>=0.0048651197969
# [12/29/2020 08:57:56 INFO 139939743401792] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=binary_classification_cross_entropy_objective, value=0.00418339715277
# [12/29/2020 08:57:56 INFO 139939743401792] Epoch 14: Loss improved. Updating best model
# [12/29/2020 08:57:56 INFO 139939743401792] Saving model for epoch: 14
# [12/29/2020 08:57:56 INFO 139939743401792] Saved checkpoint to "/tmp/tmpKokfzD/mx-mod-0000.params"
# [12/29/2020 08:57:56 INFO 139939743401792] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199365, "sum": 199365.0, "min": 199365}, "Total Batches Seen": {"count": 1, "max": 3012, "sum": 3012.0, "min": 3012}, "Total Records Seen": {"count": 1, "max": 3002475, "sum": 3002475.0, "min": 3002475}, "Max Records Seen Between Resets": {"count": 1, "max": 199365, "sum": 199365.0, "min": 199365}, "Reset Count": {"count": 1, "max": 17, "sum": 17.0, "min": 17}}, "EndTime": 1609232276.557, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609232270.516224}
#
# [12/29/2020 08:57:56 INFO 139939743401792] #throughput_metric: host=algo-1, train throughput=33002.6083255 records/second
# [12/29/2020 08:57:56 WARNING 139939743401792] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [12/29/2020 08:57:56 WARNING 139939743401792] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2020-12-29 08:57:56.564] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 33, "duration": 5, "num_examples": 1, "num_bytes": 168000}
# [2020-12-29 08:57:57.219] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 36, "duration": 653, "num_examples": 200, "num_bytes": 33493320}
# [2020-12-29 08:57:57.936] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 38, "duration": 642, "num_examples": 200, "num_bytes": 33493320}
# [12/29/2020 08:57:57 INFO 139939743401792] #train_score (algo-1) : ('binary_classification_cross_entropy_objective', 0.004137363901699895)
# [12/29/2020 08:57:57 INFO 139939743401792] #train_score (algo-1) : ('binary_classification_accuracy', 0.9614325483409826)
# [12/29/2020 08:57:57 INFO 139939743401792] #train_score (algo-1) : ('binary_f_1.000', 0.07661822985468957)
# [12/29/2020 08:57:57 INFO 139939743401792] #train_score (algo-1) : ('precision', 0.039994984954864594)
# [12/29/2020 08:57:57 INFO 139939743401792] #train_score (algo-1) : ('recall', 0.9088319088319088)
# [12/29/2020 08:57:57 INFO 139939743401792] #train_score (algo-1) : ('roc_auc_score', 0.9774616494646241)
# [12/29/2020 08:57:57 INFO 139939743401792] #quality_metric: host=algo-1, train binary_classification_cross_entropy_objective <loss>=0.0041373639017
# [12/29/2020 08:57:57 INFO 139939743401792] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.961432548341
# [12/29/2020 08:57:57 INFO 139939743401792] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.0766182298547
# [12/29/2020 08:57:57 INFO 139939743401792] #quality_metric: host=algo-1, train precision <score>=0.0399949849549
# [12/29/2020 08:57:57 INFO 139939743401792] #quality_metric: host=algo-1, train recall <score>=0.908831908832
# [12/29/2020 08:57:57 INFO 139939743401792] #quality_metric: host=algo-1, train roc_auc_score <score>=0.977461649465
# [12/29/2020 08:57:57 INFO 139939743401792] Best model found for hyperparameters: {"lr_scheduler_step": 10, "wd": 0.0001, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.1, "lr_scheduler_minimum_lr": 0.0001}
# [12/29/2020 08:57:57 INFO 139939743401792] Saved checkpoint to "/tmp/tmp1zaDY7/mx-mod-0000.params"
# [12/29/2020 08:57:57 INFO 139939743401792] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 94617.2149181366, "sum": 94617.2149181366, "min": 94617.2149181366}, "finalize.time": {"count": 1, "max": 1436.9051456451416, "sum": 1436.9051456451416, "min": 1436.9051456451416}, "initialize.time": {"count": 1, "max": 206.47501945495605, "sum": 206.47501945495605, "min": 206.47501945495605}, "check_early_stopping.time": {"count": 15, "max": 1.0039806365966797, "sum": 12.912750244140625, "min": 0.7898807525634766}, "setuptime": {"count": 1, "max": 24.47986602783203, "sum": 24.47986602783203, "min": 24.47986602783203}, "update.time": {"count": 15, "max": 6552.339792251587, "sum": 92701.44319534302, "min": 5643.632173538208}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1609232277.999228, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1609232183.57943}
# 2020-12-29 08:58:10 Uploading - Uploading generated training model
# 2020-12-29 08:58:10 Completed - Training job completed
# Training seconds: 168
# Billable seconds: 168
# CPU times: user 955 ms, sys: 31.9 ms, total: 987 ms
# Wall time: 5min 12s

# %% [markdown]
# ### Deploy and evaluate the tuned estimator
#
# Deploy the tuned predictor and evaluate it.
#
# We hypothesized that a tuned model, optimized for a higher recall, would have fewer false negatives (fraudulent transactions incorrectly labeled as valid); did the number of false negatives get reduced after tuning the model?

# %%
# %%time 
# deploy and create a predictor
recall_predictor = linear_recall.deploy(initial_instance_count=1, instance_type='ml.t2.medium')
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# -------------------!CPU times: user 353 ms, sys: 10.5 ms, total: 363 ms
# Wall time: 9min 32s

# %%
print('Metrics for tuned (recall), LinearLearner.\n')

# get metrics for tuned predictor
metrics = evaluate(recall_predictor, 
                   test_features.astype('float32'), 
                   test_labels, 
                   verbose=True)
# Out:
# Metrics for tuned (recall), LinearLearner.
#
# prediction (col)    0.0   1.0
# actual (row)
# 0.0               81913  3388
# 1.0                  10   131
#
# Recall:     0.929
# Precision:  0.037
# Accuracy:   0.960

# %% [markdown]
# ## Delete the endpoint
#
# As always, when you're done evaluating a model, you should delete the endpoint. Below, I'm using the `delete_endpoint` helper function I defined earlier.

# %%
# delete the predictor endpoint 
delete_endpoint(recall_predictor)
# Out:
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Deleted linear-learner-2020-12-29-08-59-19-145

# %% [markdown]
# ---
# ## Improvement: Managing Class Imbalance
#
# We have a model that is tuned to get a higher recall, which aims to reduce the number of false negatives. Earlier, we discussed how class imbalance may actually bias our model towards predicting that all transactions are valid, resulting in higher false negatives and true negatives. It stands to reason that this model could be further improved if we account for this imbalance.
#
# To account for class imbalance during training of a binary classifier, LinearLearner offers the hyperparameter, `positive_example_weight_mult`, which is the weight assigned to positive (1, fraudulent) examples when training a binary classifier. The weight of negative examples (0, valid) is fixed at 1.
#
# ### EXERCISE: Create a LinearLearner with a `positive_example_weight_mult` parameter
#
# In **addition** to tuning a model for higher recall (you may use `linear_recall` as a starting point), you should *add* a parameter that helps account for class imbalance. From the [hyperparameter documentation](https://docs.aws.amazon.com/sagemaker/latest/dg/ll_hyperparameters.html) on `positive_example_weight_mult`, it reads:
# > "If you want the algorithm to choose a weight so that errors in classifying negative vs. positive examples have equal impact on training loss, specify `balanced`."
#
# You could also put in a specific float value, in which case you'd want to weight positive examples more heavily than negative examples, since there are fewer of them.

# %%
# instantiate a LinearLearner

# include params for tuning for higher recall
# *and* account for class imbalance in training data
linear_balanced = LinearLearner(role=role,
                               session=sagemaker_session,
                               output_path=output_path,
                               train_instance_count=1, 
                               train_instance_type='ml.c4.xlarge',
                               predictor_type='binary_classifier',
                               epochs=15,
                               binary_classifier_model_selection_criteria='precision_at_target_recall', # target recall
                               target_recall=0.9,
                               positive_example_weight_mult='balanced',
                               )
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %% [markdown]
# ### EXERCISE: Train the balanced estimator
#
# Fit the new, balanced estimator on the formatted training data.

# %%
# %%time 
# train the estimator on formatted training data
linear_balanced.fit(formatted_train_data)
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# 2020-12-29 09:21:25 Starting - Starting the training job...
# 2020-12-29 09:21:49 Starting - Launching requested ML instancesProfilerReport-1609233685: InProgress
# ......
# 2020-12-29 09:22:50 Starting - Preparing the instances for training......
# 2020-12-29 09:23:52 Downloading - Downloading input data...
# 2020-12-29 09:24:11 Training - Downloading the training image..Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [12/29/2020 09:24:36 INFO 139841002899264] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'auto', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [12/29/2020 09:24:36 INFO 139841002899264] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {u'predictor_type': u'binary_classifier', u'feature_dim': u'30', u'binary_classifier_model_selection_criteria': u'precision_at_target_recall', u'epochs': u'15', u'positive_example_weight_mult': u'balanced', u'target_recall': u'0.9', u'mini_batch_size': u'1000'}
# [12/29/2020 09:24:36 INFO 139841002899264] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'30', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.9', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'precision_at_target_recall', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'binary_classifier', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'balanced', u'l1': u'auto', u'margin': u'1.0'}
# [12/29/2020 09:24:36 WARNING 139841002899264] Loggers have already been setup.
# Process 1 is a worker.
# [12/29/2020 09:24:36 INFO 139841002899264] Using default worker.
# [12/29/2020 09:24:37 INFO 139841002899264] Checkpoint loading and saving are disabled.
# [2020-12-29 09:24:37.222] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 28, "num_examples": 1, "num_bytes": 168000}
# [12/29/2020 09:24:37 INFO 139841002899264] Create Store: local
# [2020-12-29 09:24:37.370] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 146, "num_examples": 11, "num_bytes": 1848000}
# [12/29/2020 09:24:37 INFO 139841002899264] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f2ee1cd8d50>
# [12/29/2020 09:24:37 INFO 139841002899264] Scaling model computed with parameters:
#  {'stdev_weight':
# [4.7549789e+04 2.0122542e+00 1.7293673e+00 1.4875270e+00 1.4183073e+00
#  1.4295975e+00 1.3476098e+00 1.2706742e+00 1.2429377e+00 1.0926510e+00
#  1.0532179e+00 1.0126069e+00 9.8799181e-01 1.0078264e+00 9.4720221e-01
#  9.0296346e-01 8.6887795e-01 8.2717937e-01 8.3647752e-01 8.0705082e-01
#  8.0011046e-01 7.5549352e-01 7.2142720e-01 6.2561435e-01 6.1087644e-01
#  5.1628309e-01 4.8811832e-01 4.3569821e-01 3.6941987e-01 2.4715553e+02]
# <NDArray 30 @cpu(0)>, 'stdev_label': None, 'mean_label': None, 'mean_weight':
# [
"Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1609233891.220567}
#
# [12/29/2020 09:24:51 INFO 139841002899264] #quality_metric: host=algo-1, epoch=1, train binary_classification_weighted_cross_entropy_objective <loss>=0.440010855517
# [12/29/2020 09:24:51 INFO 139841002899264] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=binary_classification_weighted_cross_entropy_objective, value=0.410525208363
# [12/29/2020 09:24:51 INFO 139841002899264] Epoch 1: Loss improved. Updating best model
# [12/29/2020 09:24:51 INFO 139841002899264] Saving model for epoch: 1
# [12/29/2020 09:24:51 INFO 139841002899264] Saved checkpoint to "/tmp/tmpdwp2Dn/mx-mod-0000.params"
# [12/29/2020 09:24:51 INFO 139841002899264] #progress_metric: host=algo-1, completed 13 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199365, "sum": 199365.0, "min": 199365}, "Total Batches Seen": {"count": 1, "max": 412, "sum": 412.0, "min": 412}, "Total Records Seen": {"count": 1, "max": 410730, "sum": 410730.0, "min": 410730}, "Max Records Seen Between Resets": {"count": 1, "max": 199365, "sum": 199365.0, "min": 199365}, "Reset Count": {"count": 1, "max": 4, "sum": 4.0, "min": 4}}, "EndTime": 1609233891.228274, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1609233884.082267}
#
# [12/29/2020 09:24:51 INFO 139841002899264] #throughput_metric: host=algo-1, train throughput=27898.4339382 records/second
# [2020-12-29 09:24:58.072] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 7, "duration": 6842, "num_examples": 200, "num_bytes": 33493320}
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3963692446761395, "sum": 0.3963692446761395, "min": 0.3963692446761395}}, "EndTime": 1609233898.072334, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609233898.072205}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.37658528819635284, "sum": 0.37658528819635284, "min": 0.37658528819635284}}, "EndTime": 1609233898.072437, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609233898.072413}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3878151214446255, "sum": 0.3878151214446255, "min": 0.3878151214446255}}, "EndTime": 1609233898.072508, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609233898.072488}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.386415339790996, "sum": 0.386415339790996, "min": 0.386415339790996}}, "EndTime": 1609233898.072576, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609233898.072556}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5263681054810184, "sum": 0.5263681054810184, "min": 0.5263681054810184}}, "EndTime": 1609233898.072642, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609233898.072624}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6410529455443722, "sum": 0.6410529455443722, "min": 0.6410529455443722}}, "EndTime": 1609233898.072708, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609233898.07269}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5276688698811747, "sum": 0.5276688698811747, "min": 0.5276688698811747}}, "EndTime": 1609233898.072774, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609233898.072754}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6855566523374624, "sum": 0.6855566523374624, "min": 0.6855566523374624}}, "EndTime": 1609233898.072848, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609233898.072829}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.38759695940640704, "sum": 0.38759695940640704, "min": 0.38759695940640704}}, "EndTime": 1609233898.072909, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609233898.072891}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3929341817884589, "sum": 0.3929341817884589, "min": 0.3929341817884589}}, "EndTime": 1609233898.072971, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609233898.072953}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3962465970600071, "sum": 0.3962465970600071, "min": 0.3962465970600071}}, "EndTime": 1609233898.073034, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609233898.073016}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.39143113029901705, "sum": 0.39143113029901705, "min": 0.39143113029901705}}, "EndTime": 1609233898.073097, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609233898.073079}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5372409272122024, "sum": 0.5372409272122024, "min": 0.5372409272122024}}, "EndTime": 1609233898.073165, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609233898.073147}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6481122293711906, "sum": 0.6481122293711906, "min": 0.6481122293711906}}, "EndTime": 1609233898.073228, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609233898.07321}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.527004115157391, "sum": 0.527004115157391, "min": 0.527004115157391}}, "EndTime": 1609233898.073289, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609233898.073271}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6470755732167306, "sum": 0.6470755732167306, "min": 0.6470755732167306}}, "EndTime": 1609233898.073351, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609233898.073334}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5103086204337115, "sum": 0.5103086204337115, "min": 0.5103086204337115}}, "EndTime": 1609233898.073411, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609233898.073393}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5106809010721332, "sum": 0.5106809010721332, "min": 0.5106809010721332}}, "EndTime": 1609233898.073473, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609233898.073455}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5085814149942829, "sum": 0.5085814149942829, "min": 0.5085814149942829}}, "EndTime": 1609233898.073535, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609233898.073517}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.51106354840916, "sum": 0.51106354840916, "min": 0.51106354840916}}, "EndTime": 1609233898.073597, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609233898.073578}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5658717853411958, "sum": 0.5658717853411958, "min": 0.5658717853411958}}, "EndTime": 1609233898.073658, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609233898.07364}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.599927563921291, "sum": 0.599927563921291, "min": 0.599927563921291}}, "EndTime": 1609233898.073722, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609233898.073703}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5660591184146441, "sum": 0.5660591184146441, "min": 0.5660591184146441}}, "EndTime": 1609233898.073784, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609233898.073766}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5999852864251065, "sum": 0.5999852864251065, "min": 0.5999852864251065}}, "EndTime": 1609233898.073846, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609233898.073828}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.1662520978918027, "sum": 1.1662520978918027, "min": 1.1662520978918027}}, "EndTime": 1609233898.073906, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609233898.073889}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.1656566481087076, "sum": 1.1656566481087076, "min": 1.1656566481087076}}, "EndTime": 1609233898.073969, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609233898.073951}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.166466490165672, "sum": 1.166466490165672, "min": 1.166466490165672}}, "EndTime": 1609233898.074031, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609233898.074013}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.165680968011444, "sum": 1.165680968011444, "min": 1.165680968011444}}, "EndTime": 1609233898.074091, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609233898.074075}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.241220751891783, "sum": 1.241220751891783, "min": 1.241220751891783}}, "EndTime": 1609233898.074152, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609233898.074135}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.3604233597798563, "sum": 1.3604233597798563, "min": 1.3604233597798563}}, "EndTime": 1609233898.074216, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609233898.074198}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.2389932277046856, "sum": 1.2389932277046856, "min": 1.2389932277046856}}, "EndTime": 1609233898.074279, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609233898.074261}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.356852172468176, "sum": 1.356852172468176, "min": 1.356852172468176}}, "EndTime": 1609233898.07434, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609233898.074322}
#
# [12/29/2020 09:24:58 INFO 139841002899264] #quality_metric: host=algo-1, epoch=2, train binary_classification_weighted_cross_entropy_objective <loss>=0.396369244676
# [12/29/2020 09:24:58 INFO 139841002899264] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=binary_classification_weighted_cross_entropy_objective, value=0.376585288196
# [12/29/2020 09:24:58 INFO 139841002899264] Epoch 2: Loss improved. Updating best model
# [12/29/2020 09:24:58 INFO 139841002899264] Saving model for epoch: 2
# [12/29/2020 09:24:58 INFO 139841002899264] Saved checkpoint to "/tmp/tmpbyaJT3/mx-mod-0000.params"
# [12/29/2020 09:24:58 INFO 139841002899264] #progress_metric: host=algo-1, completed 20 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199365, "sum": 199365.0, "min": 199365}, "Total Batches Seen": {"count": 1, "max": 612, "sum": 612.0, "min": 612}, "Total Records Seen": {"count": 1, "max": 610095, "sum": 610095.0, "min": 610095}, "Max Records Seen Between Resets": {"count": 1, "max": 199365, "sum": 199365.0, "min": 199365}, "Reset Count": {"count": 1, "max": 5, "sum": 5.0, "min": 5}}, "EndTime": 1609233898.082887, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1609233891.229567}
#
# [12/29/2020 09:24:58 INFO 139841002899264] #throughput_metric: host=algo-1, train throughput=29089.8011392 records/second
# [2020-12-29 09:25:04.358] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 9, "duration": 6273, "num_examples": 200, "num_bytes": 33493320}
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3764211316132665, "sum": 0.3764211316132665, "min": 0.3764211316132665}}, "EndTime": 1609233904.358365, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1609233904.35825}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.36157515816233265, "sum": 0.36157515816233265, "min": 0.36157515816233265}}, "EndTime": 1609233904.358458, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1609233904.358441}
#
# ...
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.33644326011619374, "sum": 0.33644326011619374, "min": 0.33644326011619374}}, "EndTime": 1609233977.080422, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609233977.080403}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3313743017378764, "sum": 0.3313743017378764, "min": 0.3313743017378764}}, "EndTime": 1609233977.080484, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609233977.080467}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5894624262287389, "sum": 0.5894624262287389, "min": 0.5894624262287389}}, "EndTime": 1609233977.080548, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609233977.08053}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.33120755123732676, "sum": 0.33120755123732676, "min": 0.33120755123732676}}, "EndTime": 1609233977.080612, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609233977
#early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=binary_classification_weighted_cross_entropy_objective, value=0.331207551237
# [12/29/2020 09:26:17 INFO 139841002899264] Epoch 14: Loss improved. Updating best model
# [12/29/2020 09:26:17 INFO 139841002899264] Saving model for epoch: 14
# [12/29/2020 09:26:17 INFO 139841002899264] Saved checkpoint to "/tmp/tmpe8pP0r/mx-mod-0000.params"
# [12/29/2020 09:26:17 INFO 139841002899264] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199365, "sum": 199365.0, "min": 199365}, "Total Batches Seen": {"count": 1, "max": 3012, "sum": 3012.0, "min": 3012}, "Total Records Seen": {"count": 1, "max": 3002475, "sum": 3002475.0, "min": 3002475}, "Max Records Seen Between Resets": {"count": 1, "max": 199365, "sum": 199365.0, "min": 199365}, "Reset Count": {"count": 1, "max": 17, "sum": 17.0, "min": 17}}, "EndTime": 1609233977.090407, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609233970.399254}
#
# [12/29/2020 09:26:17 INFO 139841002899264] #throughput_metric: host=algo-1, train throughput=29794.7833228 records/second
# [12/29/2020 09:26:17 WARNING 139841002899264] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [12/29/2020 09:26:17 WARNING 139841002899264] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2020-12-29 09:26:17.098] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 33, "duration": 6, "num_examples": 1, "num_bytes": 168000}
# [2020-12-29 09:26:17.702] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 36, "duration": 601, "num_examples": 200, "num_bytes": 33493320}
# [2020-12-29 09:26:18.461] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 38, "duration": 688, "num_examples": 200, "num_bytes": 33493320}
# [12/29/2020 09:26:18 INFO 139841002899264] #train_score (algo-1) : ('binary_classification_weighted_cross_entropy_objective', 0.3209303206886577)
# [12/29/2020 09:26:18 INFO 139841002899264] #train_score (algo-1) : ('binary_classification_accuracy', 0.9881925112231335)
# [12/29/2020 09:26:18 INFO 139841002899264] #train_score (algo-1) : ('binary_f_1.000', 0.2116543871399866)
# [12/29/2020 09:26:18 INFO 139841002899264] #train_score (algo-1) : ('precision', 0.11992409867172675)
# [12/29/2020 09:26:18 INFO 139841002899264] #train_score (algo-1) : ('recall', 0.9002849002849003)
# [12/29/2020 09:26:18 INFO 139841002899264] #train_score (algo-1) : ('roc_auc_score', 0.9862158046004409)
# [12/29/2020 09:26:18 INFO 139841002899264] #quality_metric: host=algo-1, train binary_classification_weighted_cross_entropy_objective <loss>=0.320930320689
# [12/29/2020 09:26:18 INFO 139841002899264] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.988192511223
# [12/29/2020 09:26:18 INFO 139841002899264] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.21165438714
# [12/29/2020 09:26:18 INFO 139841002899264] #quality_metric: host=algo-1, train precision <score>=0.119924098672
# [12/29/2020 09:26:18 INFO 139841002899264] #quality_metric: host=algo-1, train recall <score>=0.900284900285
# [12/29/2020 09:26:18 INFO 139841002899264] #quality_metric: host=algo-1, train roc_auc_score <score>=0.9862158046
# [12/29/2020 09:26:18 INFO 139841002899264] Best model found for hyperparameters: {"lr_scheduler_step": 10, "wd": 0.0001, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.1, "lr_scheduler_minimum_lr": 0.0001}
# [12/29/2020 09:26:18 INFO 139841002899264] Saved checkpoint to "/tmp/tmpetdghw/mx-mod-0000.params"
# [12/29/2020 09:26:18 INFO 139841002899264] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 101576.26700401306, "sum": 101576.26700401306, "min": 101576.26700401306}, "finalize.time": {"count": 1, "max": 1426.952838897705, "sum": 1426.952838897705, "min": 1426.952838897705}, "initialize.time": {"count": 1, "max": 367.063045501709, "sum": 367.063045501709, "min": 367.063045501709}, "check_early_stopping.time": {"count": 15, "max": 1.0361671447753906, "sum": 13.370275497436523, "min": 0.8039474487304688}, "setuptime": {"count": 1, "max": 25.665998458862305, "sum": 25.665998458862305, "min": 25.665998458862305}, "update.time": {"count": 15, "max": 7143.60785484314, "sum": 99466.6850566864, "min": 6014.101028442383}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1609233978.527576, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1609233877.193532}
# Training seconds: 155
# Billable seconds: 155
# CPU times: user 797 ms, sys: 42.8 ms, total: 840 ms
# Wall time: 5min 12s

# %% [markdown]
# ### EXERCISE: Deploy and evaluate the balanced estimator
#
# Deploy the balanced predictor and evaluate it. Do the results match with your expectations?

# %%
# %%time 
# deploy and create a predictor
balanced_predictor = linear_balanced.deploy(initial_instance_count=1,instance_type='ml.t2.medium')
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# ---------------!CPU times: user 316 ms, sys: 8.74 ms, total: 324 ms
# Wall time: 7min 32s

# %%
print('Metrics for balanced, LinearLearner.\n')

# get metrics for balanced predictor
metrics = evaluate(balanced_predictor, 
                   test_features.astype('float32'), 
                   test_labels, 
                   verbose=True)
# Out:
# Metrics for balanced, LinearLearner.
#
# prediction (col)    0.0   1.0
# actual (row)
# 0.0               84276  1025
# 1.0                  12   129
#
# Recall:     0.915
# Precision:  0.112
# Accuracy:   0.988

# %% [markdown]
# ## Delete the endpoint
#
# When you're done evaluating a model, you should delete the endpoint.

# %%
# delete the predictor endpoint 
delete_endpoint(balanced_predictor)
# Out:
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Deleted linear-learner-2020-12-29-09-26-59-933

# %% [markdown]
# A note on metric variability:
#
# The above model is tuned for the best possible precision with recall fixed at about 90%. The recall is fixed at 90% during training, but may vary when we apply our trained model to a test set of data.

# %% [markdown]
# ---
# ## Model Design
#
# Now that you've seen how to tune and balance a LinearLearner. Create, train and deploy your own model. This exercise is meant to be more open-ended, so that you get practice with the steps involved in designing a model and deploying it.
#
# ### EXERCISE: Train and deploy a LinearLearner with appropriate hyperparameters, according to the given scenario
#
# **Scenario:**
# * A bank has asked you to build a model that optimizes for a good user experience; users should only ever have up to about 15% of their valid transactions flagged as fraudulent.
#
# This requires that you make a design decision: Given the above scenario, what metric (and value) should you aim for during training?
#
# You may assume that performance on a training set will be within about 5-10% of the performance on a test set. For example, if you get 80% on a training set, you can assume that you'll get between about 70-90% accuracy on a test set.
#
# Your final model should account for class imbalance and be appropriately tuned.

# %%
# %%time
# instantiate and train a LinearLearner

# include params for tuning for higher precision
# *and* account for class imbalance in training data
linear_precision = LinearLearner(role=role,
                                train_instance_count=1, 
                                train_instance_type='ml.c4.xlarge',
                                predictor_type='binary_classifier',
                                output_path=output_path,
                                sagemaker_session=sagemaker_session,
                                epochs=15,
                                binary_classifier_model_selection_criteria='recall_at_target_precision',
                                target_precision=0.9,
                                positive_example_weight_mult='balanced')


# train the estimator on formatted training data
linear_precision.fit(formatted_train_data)
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# 2020-12-29 10:48:46 Starting - Starting the training job...
# 2020-12-29 10:48:50 Starting - Launching requested ML instancesProfilerReport-1609238926: InProgress
# .........
# 2020-12-29 10:50:47 Starting - Preparing the instances for training......
# 2020-12-29 10:51:27 Downloading - Downloading input data...
# 2020-12-29 10:52:08 Training - Training image download completed. Training in progress.Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [12/29/2020 10:52:07 INFO 139928730535744] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'auto', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [12/29/2020 10:52:07 INFO 139928730535744] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {u

#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5808202512348117, "sum": 0.5808202512348117, "min": 0.5808202512348117}}, "EndTime": 1609239223.115363, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609239223.115345}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5100766899837321, "sum": 0.5100766899837321, "min": 0.5100766899837321}}, "EndTime": 1609239223.115433, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609239223.115415}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5808143151058025, "sum": 0.5808143151058025, "min": 0.5808143151058025}}, "EndTime": 1609239223.115497, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609239223.115479}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.1615434824881241, "sum": 1.1615434824881241, "min": 1.1615434824881241}}, "EndTime": 1609239223.115566, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609239223.115548}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.1657150569129828, "sum": 1.1657150569129828, "min": 1.1657150569129828}}, "EndTime": 1609239223.115613, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609239223.115599}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.1615423265006675, "sum": 1.1615423265006675, "min": 1.1615423265006675}}, "EndTime": 1609239223.115655, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609239223.115646}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.165713624887131, "sum": 1.165713624887131, "min": 1.165713624887131}}, "EndTime": 1609239223.115683, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609239223.115676}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.1653917168852073, "sum": 1.1653917168852073, "min": 1.1653917168852073}}, "EndTime": 1609239223.115721, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609239223.115707}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.2832254137202124, "sum": 1.2832254137202124, "min": 1.2832254137202124}}, "EndTime": 1609239223.115787, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609239223.115769}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.1653905556836919, "sum": 1.1653905556836919, "min": 1.1653905556836919}}, "EndTime": 1609239223.115851, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609239223.115834}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.2832145643378023, "sum": 1.2832145643378023, "min": 1.2832145643378023}}, "EndTime": 1609239223.115909, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609239223.115893}
#
# [12/29/2020 10:53:43 INFO 139928730535744] #quality_metric: host=algo-1, epoch=14, train binary_classification_weighted_cross_entropy_objective <loss>=0.339684555514
# [12/29/2020 10:53:43 INFO 139928730535744] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=binary_classification_weighted_cross_entropy_objective, value=0.331207551237
# [12/29/2020 10:53:43 INFO 139928730535744] Epoch 14: Loss improved. Updating best model
# [12/29/2020 10:53:43 INFO 139928730535744] Saving model for epoch: 14
# [12/29/2020 10:53:43 INFO 139928730535744] Saved checkpoint to "/tmp/tmpqsIwQf/mx-mod-0000.params"
# [12/29/2020 10:53:43 INFO 139928730535744] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199365, "sum": 199365.0, "min": 199365}, "Total Batches Seen": {"count": 1, "max": 3012, "sum": 3012.0, "min": 3012}, "Total Records Seen": {"count": 1, "max": 3002475, "sum": 3002475.0, "min": 3002475}, "Max Records Seen Between Resets": {"count": 1, "max": 199365, "sum": 199365.0, "min": 199365}, "Reset Count": {"count": 1, "max": 17, "sum": 17.0, "min": 17}}, "EndTime": 1609239223.123977, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1609239216.381138}
#
# [12/29/2020 10:53:43 INFO 139928730535744] #throughput_metric: host=algo-1, train throughput=29566.3578134 records/second
# [12/29/2020 10:53:43 WARNING 139928730535744] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [12/29/2020 10:53:43 WARNING 139928730535744] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2020-12-29 10:53:43.131] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 33, "duration": 5, "num_examples": 1, "num_bytes": 168000}
# [2020-12-29 10:53:43.797] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 36, "duration": 663, "num_examples": 200, "num_bytes": 33493320}
# [2020-12-29 10:53:44.594] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 38, "duration": 726, "num_examples": 200, "num_bytes": 33493320}
# [12/29/2020 10:53:44 INFO 139928730535744] #train_score (algo-1) : ('binary_classification_weighted_cross_entropy_objective', 0.3209303206886577)
# [12/29/2020 10:53:44 INFO 139928730535744] #train_score (algo-1) : ('binary_classification_accuracy', 0.2712763022596745)
# [12/29/2020 10:53:44 INFO 139928730535744] #train_score (algo-1) : ('binary_f_1.000', 0.004808746163963174)
# [12/29/2020 10:53:44 INFO 139928730535744] #train_score (algo-1) : ('precision', 0.0024101680251042003)
# [12/29/2020 10:53:44 INFO 139928730535744] #train_score (algo-1) : ('recall', 1.0)
# [12/29/2020 10:53:44 INFO 139928730535744] #train_score (algo-1) : ('roc_auc_score', 0.9862158046004409)
# [12/29/2020 10:53:44 INFO 139928730535744] #quality_metric: host=algo-1, train binary_classification_weighted_cross_entropy_objective <loss>=0.320930320689
# [12/29/2020 10:53:44 INFO 139928730535744] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.27127630226
# [12/29/2020 10:53:44 INFO 139928730535744] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.00480874616396
# [12/29/2020 10:53:44 INFO 139928730535744] #quality_metric: host=algo-1, train precision <score>=0.0024101680251
# [12/29/2020 10:53:44 INFO 139928730535744] #quality_metric: host=algo-1, train recall <score>=1.0
# [12/29/2020 10:53:44 INFO 139928730535744] #quality_metric: host=algo-1, train roc_auc_score <score>=0.9862158046
# [12/29/2020 10:53:44 INFO 139928730535744] Best model found for hyperparameters: {"lr_scheduler_step": 10, "wd": 0.0001, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.1, "lr_scheduler_minimum_lr": 0.0001}
# [12/29/2020 10:53:44 INFO 139928730535744] Saved checkpoint to "/tmp/tmpSFVzMh/mx-mod-0000.params"
# [12/29/2020 10:53:44 INFO 139928730535744] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 97527.97198295593, "sum": 97527.97198295593, "min": 97527.97198295593}, "finalize.time": {"count": 1, "max": 1528.761863708496, "sum": 1528.761863708496, "min": 1528.761863708496}, "initialize.time": {"count": 1, "max": 306.77294731140137, "sum": 306.77294731140137, "min": 306.77294731140137}, "check_early_stopping.time": {"count": 15, "max": 1.09100341796875, "sum": 12.861967086791992, "min": 0.782012939453125}, "setuptime": {"count": 1, "max": 25.955915451049805, "sum": 25.955915451049805, "min": 25.955915451049805}, "update.time": {"count": 15, "max": 6846.274137496948, "sum": 95390.48957824707, "min": 5674.068927764893}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1609239224.663449, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1609239127.364631}
# 2020-12-29 10:54:09 Uploading - Uploading generated training model
# 2020-12-29 10:54:09 Completed - Training job completed
# ProfilerReport-1609238926: NoIssuesFound
# Training seconds: 151
# Billable seconds: 151
# CPU times: user 898 ms, sys: 30.1 ms, total: 928 ms
# Wall time: 5min 43s

# %%
# %%time 
# deploy and evaluate a predictor
precision_predictor = linear_precision.deploy(initial_instance_count=1, instance_type='ml.t2.medium')
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# ---------------!prediction (col)    0.0    1.0
# actual (row)
# 0.0               23300  62001
# 1.0                   0    141
#
# Recall:     1.000
# Precision:  0.002
# Accuracy:   0.274
#
# CPU times: user 6.4 s, sys: 56.5 ms, total: 6.46 s
# Wall time: 7min 45s

# %%
print('Metrics for tuned (precision), LinearLearner.\n')

# get metrics for balanced predictor
metrics = evaluate(precision_predictor, 
                   test_features.astype('float32'), 
                   test_labels, 
                   verbose=True)
# Out:
# prediction (col)    0.0    1.0
# actual (row)
# 0.0               23300  62001
# 1.0                   0    141
#
# Recall:     1.000
# Precision:  0.002
# Accuracy:   0.274

# %%
## IMPORTANT
# delete the predictor endpoint after evaluation 
delete_endpoint(predictor)
# Out:
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Already deleted: linear-learner-2020-12-29-09-50-42-662

# %% [markdown]
# ## Final Cleanup!
#
# * Double check that you have deleted all your endpoints.
# * I'd also suggest manually deleting your S3 bucket, models, and endpoint configurations directly from your AWS console.
#
# You can find thorough cleanup instructions, [in the documentation](https://docs.aws.amazon.com/sagemaker/latest/dg/ex1-cleanup.html).

# %% [markdown]
# ---
# # Conclusion
#
# In this notebook, you saw how to train and deploy a LinearLearner in SageMaker. This model is well-suited for a binary classification task that involves specific design decisions and managing class imbalance in the training set.
#
# Following the steps of a machine learning workflow, you loaded in some credit card transaction data, explored that data and prepared it for model training. Then trained, deployed, and evaluated several models, according to different design considerations!
